# %%
# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from mlxtend.frequent_patterns import apriori, association_rules

# %%
# Data Preprocessing and Cleaning
data = pd.read_csv('transaction_data.csv')

# %%
data.head()
# Out:
#    UserId  TransactionId               TransactionTime  ItemCode  \
# 0  278166        6355745  Sat Feb 02 12:50:00 IST 2019    465549
# 1  337701        6283376  Wed Dec 26 09:06:00 IST 2018    482370
# 2  267099        6385599  Fri Feb 15 09:45:00 IST 2019    490728
# 3  380478        6044973  Fri Jun 22 07:14:00 IST 2018    459186
# 4      -1        6143225  Mon Sep 10 11:58:00 IST 2018   1733592
#
#                      ItemDescription  NumberOfItemsPurchased  CostPerItem  \
# 0   FAMILY ALBUM WHITE PICTURE FRAME                       6        11.73
# 1              LONDON BUS COFFEE MUG                       3         3.52
# 2  SET 12 COLOUR PENCILS DOLLY GIRL                       72         0.90
# 3        UNION JACK FLAG LUGGAGE TAG                       3         1.73
# 4                WASHROOM METAL SIGN                       3         3.40
#
#           Country
# 0  United Kingdom
# 1  United Kingdom
# 2          France
# 3  United Kingdom
# 4  United Kingdom

# %%
# Exploring the different regions of transactions 
data.Country.unique()
# Out:
# array(['United Kingdom', 'France', 'Austria', 'Australia', 'EIRE',
#        'Portugal', 'Germany', 'Sweden', 'Cyprus', 'Spain', 'Japan',
#        'Belgium', 'Singapore', 'Denmark', 'Netherlands', 'Norway',
#        'Canada', 'Iceland', 'Switzerland', 'Poland', 'Finland',
#        'Hong Kong', 'Italy', 'Malta', 'Israel', 'Channel Islands',
#        'Unspecified', 'USA', 'Czech Republic', 'Lebanon', 'Brazil',
#        'European Community', 'Greece', 'RSA', 'Bahrain', 'Lithuania',
#        'United Arab Emirates', 'Saudi Arabia'], dtype=object)

# %%
# Stripping extra spaces in the ItemDescription 
data['ItemDescription'] = data['ItemDescription'].str.strip() 
  
# Dropping the rows without any TransactionId number 
data.dropna(axis = 0, subset =['TransactionId'], inplace = True) 
data['TransactionId'] = data['TransactionId'].astype('str') 
  
# Dropping all transactions which were done on credit 
data = data[~data['TransactionId'].str.contains('C')]

# %%
data['Country'].value_counts()
# Out:
# United Kingdom          990956
# Germany                  18990
# France                   17114
# EIRE                     16392
# Spain                     5066
# Netherlands               4742
# Belgium                   4138
# Switzerland               4004
# Portugal                  3038
# Australia                 2518
# Norway                    2172
# Italy                     1606
# Channel Islands           1516
# Finland                   1390
# Cyprus                    1244
# Sweden                     924
# Unspecified                892
# Austria                    802
# Denmark                    778
# Japan                      716
# Poland                     682
# Israel                     594
# USA                        582
# Hong Kong                  576
# Singapore                  458
# Iceland                    364
# Canada                     302
# Greece                     292
# Malta                      254
# United Arab Emirates       136
# European Community         122
# RSA                        116
# Lebanon                     90
# Lithuania                   70
# Brazil                      64
# Czech Republic              60
# Bahrain                     38
# Saudi Arabia                20
# Name: Country, dtype: int64

# %%
# Transactions done in France 
basket_France = (data[data['Country'] =="France"] 
          .groupby(['TransactionId', 'ItemDescription'])['NumberOfItemsPurchased'] 
          .sum().unstack().reset_index().fillna(0) 
          .set_index('TransactionId'))

# %%
# One Hot Encoding 
def hot_encode(x): 
    if(x<= 0): 
        return 0
    if(x>= 1): 
        return 1

# %%
# Encoded Basket for France 
basket_encoded = basket_France.applymap(hot_encode) 
basket_France = basket_encoded

# %%
# Building the model 
frq_items = apriori(basket_France, min_support = 0.05, use_colnames = True) 
  
# Collecting the inferred rules in a dataframe 
rules = association_rules(frq_items, metric ="lift", min_threshold = 1) 
rules = rules.sort_values(['confidence', 'lift'], ascending =[False, False]) 
print(rules.head())
# Out:
#                                            antecedents  \
# 25                        (JUMBO BAG WOODLAND ANIMALS)
# 186  (SET/20 RED RETROSPOT PAPER NAPKINS, SET/6 RED...
# 184  (SET/6 RED SPOTTY PAPER PLATES, SET/20 RED RET...
# 193  (POSTAGE, SET/20 RED RETROSPOT PAPER NAPKINS, ...
# 190  (SET/6 RED SPOTTY PAPER PLATES, POSTAGE, SET/2...
#
#                          consequents  antecedent support  consequent support  \
# 25                         (POSTAGE)            0.065076            0.650759
# 186  (SET/6 RED SPOTTY PAPER PLATES)            0.086768            0.108460
# 184    (SET/6 RED SPOTTY PAPER CUPS)            0.086768            0.117137
# 193  (SET/6 RED SPOTTY PAPER PLATES)            0.071584            0.108460
# 190    (SET/6 RED SPOTTY PAPER CUPS)            0.071584            0.117137
#
#       support  confidence      lift  leverage  conviction
# 25   0.065076    1.000000  1.536667  0.022727         inf
# 186  0.084599    0.975000  8.989500  0.075188   35.661605
# 184  0.084599    0.975000  8.323611  0.074435   35.314534
# 193  0.069414    0.969697  8.940606  0.061650   29.420824
# 190  0.069414    0.969697  8.278339  0.061029   29.134490

# %%
# Make count of antecendents and consequents in a Rule
rules["antecedent_len"] = rules["antecedents"].apply(lambda x: len(x))
rules["consequents_len"] = rules["consequents"].apply(lambda x: len(x))
rules
# Out:
#                                            antecedents  \
# 25                        (JUMBO BAG WOODLAND ANIMALS)
# 186  (SET/20 RED RETROSPOT PAPER NAPKINS, SET/6 RED...
# 184  (SET/6 RED SPOTTY PAPER PLATES, SET/20 RED RET...
# 193  (POSTAGE, SET/20 RED RETROSPOT PAPER NAPKINS, ...
# 190  (SET/6 RED SPOTTY PAPER PLATES, POSTAGE, SET/2...
# 74                          (RED RETROSPOT PICNIC BAG)
# 87                     (SET OF 9 BLACK SKULL BALLOONS)
# 110                    (SET/6 RED SPOTTY PAPER PLATES)
# 48                        (PACK OF 6 SKULL PAPER CUPS)
# 178           (SET/6 RED SPOTTY PAPER PLATES, POSTAGE)
# 101                          (TEA PARTY BIRTHDAY CARD)
# 98                 (STRAWBERRY LUNCH BOX WITH CUTLERY)
# 82                (ROUND SNACK BOXES SET OF4 WOODLAND)
# 14                        (CHILDRENS CUTLERY SPACEBOY)
# 13                        (ASSORTED COLOUR MINI CASES)
# 84               (SET OF 2 TEA TOWELS APPLE AND PEARS)
# 138  (LUNCH BAG RED RETROSPOT, LUNCH BAG APPLE DESIGN)
# 10                          (ALARM CLOCK BAKELIKE RED)
# 125  (ALARM CLOCK BAKELIKE RED, ALARM CLOCK BAKELIK...
# 102                           (WOODLAND CHARLOTTE BAG)
# 131  (ALARM CLOCK BAKELIKE RED, ALARM CLOCK BAKELIK...
# 15                      (CHILDRENS CUTLERY DOLLY GIRL)
# 111                      (SET/6 RED SPOTTY PAPER CUPS)
# 17                          (COFFEE MUG APPLES DESIGN)
# 80                 (ROUND SNACK BOXES SET OF 4 FRUITS)
# 59                     (PLASTERS IN TIN CIRCUS PARADE)
# 69                                (RABBIT NIGHT LIGHT)
# 9                          (ALARM CLOCK BAKELIKE PINK)
# 53                           (PAPER BUNTING RETROSPOT)
# 76                     (RED TOADSTOOL LED NIGHT LIGHT)
# ..                                                 ...
# 100                                          (POSTAGE)
# 8                                            (POSTAGE)
# 11                                           (POSTAGE)
# 4                                            (POSTAGE)
# 50                                           (POSTAGE)
# 157                                          (POSTAGE)
# 169                                          (POSTAGE)
# 176                                          (POSTAGE)
# 163                                          (POSTAGE)
# 23                                           (POSTAGE)
# 71                                           (POSTAGE)
# 201                                          (POSTAGE)
# 46                                           (POSTAGE)
# 24                                           (POSTAGE)
# 151                                          (POSTAGE)
# 18                                           (POSTAGE)
# 128                                          (POSTAGE)
# 52                                           (POSTAGE)
# 75                                           (POSTAGE)
# 103                                          (POSTAGE)
# 134                                          (POSTAGE)
# 86                                           (POSTAGE)
# 12                                           (POSTAGE)
# 85                                           (POSTAGE)
# 88                                           (POSTAGE)
# 64                                           (POSTAGE)
# 49                                           (POSTAGE)
# 139                                          (POSTAGE)
# 16                                           (POSTAGE)
# 121                                          (POSTAGE)
#
#                                            consequents  antecedent support  \
# 25                                           (POSTAGE)            0.065076
# 186                    (SET/6 RED SPOTTY PAPER PLATES)            0.086768
# 184                      (SET/6 RED SPOTTY PAPER CUPS)            0.086768
# 193                    (SET/6 RED SPOTTY PAPER PLATES)            0.071584
# 190                      (SET/6 RED SPOTTY PAPER CUPS)            0.071584
# 74                                           (POSTAGE)            0.060738
# 87                                           (POSTAGE)            0.056399
# 110                      (SET/6 RED SPOTTY PAPER CUPS)            0.108460
# 48                                           (POSTAGE)            0.054230
# 178                      (SET/6 RED SPOTTY PAPER CUPS)            0.091106
# 101                                          (POSTAGE)            0.080260
# 98                                           (POSTAGE)            0.104121
# 82                                           (POSTAGE)            0.134490
# 14                      (CHILDRENS CUTLERY DOLLY GIRL)            0.058568
# 13                                           (POSTAGE)            0.058568
# 84                                           (POSTAGE)            0.058568
# 138                                          (POSTAGE)            0.056399
# 10                                           (POSTAGE)            0.080260
# 125                                          (POSTAGE)            0.067245
# 102                                          (POSTAGE)            0.062907
# 131                                          (POSTAGE)            0.062907
# 15                        (CHILDRENS CUTLERY SPACEBOY)            0.060738
# 111                    (SET/6 RED SPOTTY PAPER PLATES)            0.117137
# 17                                           (POSTAGE)            0.058568
# 80                                           (POSTAGE)            0.091106
# 59                                           (POSTAGE)            0.143167
# 69                                           (POSTAGE)            0.160521
# 9                                            (POSTAGE)            0.086768
# 53                                           (POSTAGE)            0.069414
# 76                                           (POSTAGE)            0.154013
# ..                                                 ...                 ...
# 100                          (TEA PARTY BIRTHDAY CARD)            0.650759
# 8                          (ALARM CLOCK BAKELIKE PINK)            0.650759
# 11                          (ALARM CLOCK BAKELIKE RED)            0.650759
# 4                         (ALARM CLOCK BAKELIKE GREEN)            0.650759
# 50                   (PACK OF 72 RETROSPOT CAKE CASES)            0.650759
# 157  (PLASTERS IN TIN WOODLAND ANIMALS, PLASTERS IN...            0.650759
# 169  (SET/20 RED RETROSPOT PAPER NAPKINS, SET/6 RED...            0.650759
# 176  (SET/6 RED SPOTTY PAPER PLATES, SET/20 RED RET...            0.650759
# 163  (PLASTERS IN TIN WOODLAND ANIMALS, PLASTERS IN...            0.650759
# 23                           (JUMBO BAG RED RETROSPOT)            0.650759
# 71                       (RED RETROSPOT CHARLOTTE BAG)            0.650759
# 201  (SET/6 RED SPOTTY PAPER PLATES, SET/20 RED RET...            0.650759
# 46                            (MINI PAINT SET VINTAGE)            0.650759
# 24                        (JUMBO BAG WOODLAND ANIMALS)            0.650759
# 151  (PLASTERS IN TIN CIRCUS PARADE, PLASTERS IN TI...            0.650759
# 18                              (DOLLY GIRL LUNCH BOX)            0.650759
# 128  (ALARM CLOCK BAKELIKE RED, ALARM CLOCK BAKELIK...            0.650759
# 52                           (PAPER BUNTING RETROSPOT)            0.650759
# 75                          (RED RETROSPOT PICNIC BAG)            0.650759
# 103                           (WOODLAND CHARLOTTE BAG)            0.650759
# 134  (ALARM CLOCK BAKELIKE RED, ALARM CLOCK BAKELIK...            0.650759
# 86                     (SET OF 9 BLACK SKULL BALLOONS)            0.650759
# 12                        (ASSORTED COLOUR MINI CASES)            0.650759
# 85               (SET OF 2 TEA TOWELS APPLE AND PEARS)            0.650759
# 88                 (SET/10 RED POLKADOT PARTY CANDLES)            0.650759
# 64                         (PLASTERS IN TIN STRONGMAN)            0.650759
# 49                        (PACK OF 6 SKULL PAPER CUPS)            0.650759
# 139  (LUNCH BAG RED RETROSPOT, LUNCH BAG APPLE DESIGN)            0.650759
# 16                          (COFFEE MUG APPLES DESIGN)            0.650759
# 121  (ALARM CLOCK BAKELIKE GREEN, ALARM CLOCK BAKEL...            0.650759
#
#      consequent support   support  confidence       lift  leverage  \
# 25             0.650759  0.065076    1.000000   1.536667  0.022727
# 186            0.108460  0.084599    0.975000   8.989500  0.075188
# 184            0.117137  0.084599    0.975000   8.323611  0.074435
# 193            0.108460  0.069414    0.969697   8.940606  0.061650
# 190            0.117137  0.069414    0.969697   8.278339  0.061029
# 74             0.650759  0.058568    0.964286   1.481786  0.019043
# 87             0.650759  0.054230    0.961538   1.477564  0.017528
# 110            0.117137  0.104121    0.960000   8.195556  0.091417
# 48             0.650759  0.052061    0.960000   1.475200  0.016770
# 178            0.117137  0.086768    0.952381   8.130511  0.076096
# 101            0.650759  0.075922    0.945946   1.453604  0.023692
# 98             0.650759  0.097614    0.937500   1.440625  0.029856
# 82             0.650759  0.125813    0.935484   1.437527  0.038293
# 14             0.060738  0.054230    0.925926  15.244709  0.050673
# 13             0.650759  0.054230    0.925926   1.422840  0.016116
# 84             0.650759  0.054230    0.925926   1.422840  0.016116
# 138            0.650759  0.052061    0.923077   1.418462  0.015358
# 10             0.650759  0.073753    0.918919   1.412072  0.021523
# 125            0.650759  0.060738    0.903226   1.387957  0.016977
# 102            0.650759  0.056399    0.896552   1.377701  0.015462
# 131            0.650759  0.056399    0.896552   1.377701  0.015462
# 15             0.058568  0.054230    0.892857  15.244709  0.050673
# 111            0.108460  0.104121    0.888889   8.195556  0.091417
# 17             0.650759  0.052061    0.888889   1.365926  0.013947
# 80             0.650759  0.080260    0.880952   1.353730  0.020972
# 59             0.650759  0.125813    0.878788   1.350404  0.032646
# 69             0.650759  0.140998    0.878378   1.349775  0.036538
# 9              0.650759  0.075922    0.875000   1.344583  0.019457
# 53             0.650759  0.060738    0.875000   1.344583  0.015566
# 76             0.650759  0.134490    0.873239   1.341878  0.034265
# ..                  ...       ...         ...        ...       ...
# 100            0.080260  0.075922    0.116667   1.453604  0.023692
# 8              0.086768  0.075922    0.116667   1.344583  0.019457
# 11             0.080260  0.073753    0.113333   1.412072  0.021523
# 4              0.082430  0.071584    0.110000   1.334474  0.017942
# 50             0.086768  0.071584    0.110000   1.267750  0.015119
# 157            0.086768  0.071584    0.110000   1.267750  0.015119
# 169            0.086768  0.071584    0.110000   1.267750  0.015119
# 176            0.086768  0.071584    0.110000   1.267750  0.015119
# 163            0.088937  0.071584    0.110000   1.236829  0.013707
# 23             0.082430  0.069414    0.106667   1.294035  0.015773
# 71             0.082430  0.069414    0.106667   1.294035  0.015773
# 201            0.084599  0.069414    0.106667   1.260855  0.014361
# 46             0.088937  0.069414    0.106667   1.199350  0.011538
# 24             0.065076  0.065076    0.100000   1.536667  0.022727
# 151            0.075922  0.062907    0.096667   1.273238  0.013500
# 18             0.084599  0.062907    0.096667   1.142650  0.007853
# 128            0.067245  0.060738    0.093333   1.387957  0.016977
# 52             0.069414  0.060738    0.093333   1.344583  0.015566
# 75             0.060738  0.058568    0.090000   1.481786  0.019043
# 103            0.062907  0.056399    0.086667   1.377701  0.015462
# 134            0.062907  0.056399    0.086667   1.377701  0.015462
# 86             0.056399  0.054230    0.083333   1.477564  0.017528
# 12             0.058568  0.054230    0.083333   1.422840  0.016116
# 85             0.058568  0.054230    0.083333   1.422840  0.016116
# 88             0.065076  0.054230    0.083333   1.280556  0.011881
# 64             0.069414  0.054230    0.083333   1.200521  0.009058
# 49             0.054230  0.052061    0.080000   1.475200  0.016770
# 139            0.056399  0.052061    0.080000   1.418462  0.015358
# 16             0.058568  0.052061    0.080000   1.365926  0.013947
# 121            0.062907  0.052061    0.080000   1.271724  0.011124
#
#      conviction  antecedent_len  consequents_len
# 25          inf               1                1
# 186   35.661605               2                1
# 184   35.314534               2                1
# 193   29.420824               3                1
# 190   29.134490               3                1
# 74     9.778742               1                1
# 87     9.080260               1                1
# 110   22.071584               1                1
# 48     8.731020               1                1
# 178   18.540130               2                1
# 101    6.460954               1                1
# 98     5.587852               1                1
# 82     5.413232               1                1
# 14    12.680043               1                1
# 13     4.714751               1                1
# 84     4.714751               1                1
# 138    4.540130               2                1
# 10     4.307303               1                1
# 125    3.608821               2                1
# 102    3.375994               1                1
# 131    3.375994               2                1
# 15     8.786696               1                1
# 111    8.023861               1                1
# 17     3.143167               1                1
# 80     2.933623               1                1
# 59     2.881236               1                1
# 69     2.871535               1                1
# 9      2.793926               1                1
# 53     2.793926               1                1
# 76     2.755122               1                1
# ..          ...             ...              ...
# 100    1.041215               1                1
# 8      1.033848               1                1
# 11     1.037300               1                1
# 4      1.030978               1                1
# 50     1.026103               1                1
# 157    1.026103               1                2
# 169    1.026103               1                2
# 176    1.026103               1                2
# 163    1.023666               1                2
# 23     1.027131               1                1
# 71     1.027131               1                1
# 201    1.024703               1                3
# 46     1.019847               1                1
# 24     1.038805               1                1
# 151    1.022965               1                2
# 18     1.013359               1                1
# 128    1.028774               1                2
# 52     1.026381               1                1
# 75     1.032157               1                1
# 103    1.026015               1                1
# 134    1.026015               1                2
# 86     1.029383               1                1
# 12     1.027016               1                1
# 85     1.027016               1                1
# 88     1.019917               1                1
# 64     1.015184               1                1
# 49     1.028011               1                1
# 139    1.025653               1                2
# 16     1.023295               1                1
# 121    1.018580               1                2
#
# [204 rows x 11 columns]

# %%
# Given Assignment Mentioned 2 Consequents
rules =rules[rules['consequents_len'] >= 2]
rules.head()
# Out:
#                                            antecedents  \
# 199  (SET/20 RED RETROSPOT PAPER NAPKINS, SET/6 RED...
# 195  (SET/6 RED SPOTTY PAPER PLATES, SET/20 RED RET...
# 181                    (SET/6 RED SPOTTY PAPER PLATES)
# 187                    (SET/6 RED SPOTTY PAPER PLATES)
# 194           (SET/6 RED SPOTTY PAPER PLATES, POSTAGE)
#
#                                            consequents  antecedent support  \
# 199           (SET/6 RED SPOTTY PAPER PLATES, POSTAGE)            0.086768
# 195             (POSTAGE, SET/6 RED SPOTTY PAPER CUPS)            0.086768
# 181             (POSTAGE, SET/6 RED SPOTTY PAPER CUPS)            0.108460
# 187  (SET/20 RED RETROSPOT PAPER NAPKINS, SET/6 RED...            0.108460
# 194  (SET/20 RED RETROSPOT PAPER NAPKINS, SET/6 RED...            0.091106
#
#      consequent support   support  confidence      lift  leverage  conviction  \
# 199            0.091106  0.069414    0.800000  8.780952  0.061509    4.544469
# 195            0.099783  0.069414    0.800000  8.017391  0.060756    4.501085
# 181            0.099783  0.086768    0.800000  8.017391  0.075945    4.501085
# 187            0.086768  0.084599    0.780000  8.989500  0.075188    4.151055
# 194            0.086768  0.069414    0.761905  8.780952  0.061509    3.835575
#
#      antecedent_len  consequents_len
# 199               2                2
# 195               2                2
# 181               1                2
# 187               1                2
# 194               2                2

# %%
rules.count()
# Out:
# antecedents           49
# consequents           49
# antecedent support    49
# consequent support    49
# support               49
# confidence            49
# lift                  49
# leverage              49
# conviction            49
# antecedent_len        49
# consequents_len       49
# dtype: int64

# %%
#Calculate support to remove unuseful rules
rules =rules[rules['support']>0.007]
rules.head()
# Out:
#                                            antecedents  \
# 199  (SET/20 RED RETROSPOT PAPER NAPKINS, SET/6 RED...
# 195  (SET/6 RED SPOTTY PAPER PLATES, SET/20 RED RET...
# 181                    (SET/6 RED SPOTTY PAPER PLATES)
# 187                    (SET/6 RED SPOTTY PAPER PLATES)
# 194           (SET/6 RED SPOTTY PAPER PLATES, POSTAGE)
#
#                                            consequents  antecedent support  \
# 199           (SET/6 RED SPOTTY PAPER PLATES, POSTAGE)            0.086768
# 195             (POSTAGE, SET/6 RED SPOTTY PAPER CUPS)            0.086768
# 181             (POSTAGE, SET/6 RED SPOTTY PAPER CUPS)            0.108460
# 187  (SET/20 RED RETROSPOT PAPER NAPKINS, SET/6 RED...            0.108460
# 194  (SET/20 RED RETROSPOT PAPER NAPKINS, SET/6 RED...            0.091106
#
#      consequent support   support  confidence      lift  leverage  conviction  \
# 199            0.091106  0.069414    0.800000  8.780952  0.061509    4.544469
# 195            0.099783  0.069414    0.800000  8.017391  0.060756    4.501085
# 181            0.099783  0.086768    0.800000  8.017391  0.075945    4.501085
# 187            0.086768  0.084599    0.780000  8.989500  0.075188    4.151055
# 194            0.086768  0.069414    0.761905  8.780952  0.061509    3.835575
#
#      antecedent_len  consequents_len
# 199               2                2
# 195               2                2
# 181               1                2
# 187               1                2
# 194               2                2

# %%
rules.count()
# Out:
# antecedents           49
# consequents           49
# antecedent support    49
# consequent support    49
# support               49
# confidence            49
# lift                  49
# leverage              49
# conviction            49
# antecedent_len        49
# consequents_len       49
# dtype: int64

# %%
#Calculate support to remove unuseful Rules
rules =rules[rules['consequent support']>0.005]
rules.head()
# Out:
#                                            antecedents  \
# 199  (SET/20 RED RETROSPOT PAPER NAPKINS, SET/6 RED...
# 195  (SET/6 RED SPOTTY PAPER PLATES, SET/20 RED RET...
# 181                    (SET/6 RED SPOTTY PAPER PLATES)
# 187                    (SET/6 RED SPOTTY PAPER PLATES)
# 194           (SET/6 RED SPOTTY PAPER PLATES, POSTAGE)
#
#                                            consequents  antecedent support  \
# 199           (SET/6 RED SPOTTY PAPER PLATES, POSTAGE)            0.086768
# 195             (POSTAGE, SET/6 RED SPOTTY PAPER CUPS)            0.086768
# 181             (POSTAGE, SET/6 RED SPOTTY PAPER CUPS)            0.108460
# 187  (SET/20 RED RETROSPOT PAPER NAPKINS, SET/6 RED...            0.108460
# 194  (SET/20 RED RETROSPOT PAPER NAPKINS, SET/6 RED...            0.091106
#
#      consequent support   support  confidence      lift  leverage  conviction  \
# 199            0.091106  0.069414    0.800000  8.780952  0.061509    4.544469
# 195            0.099783  0.069414    0.800000  8.017391  0.060756    4.501085
# 181            0.099783  0.086768    0.800000  8.017391  0.075945    4.501085
# 187            0.086768  0.084599    0.780000  8.989500  0.075188    4.151055
# 194            0.086768  0.069414    0.761905  8.780952  0.061509    3.835575
#
#      antecedent_len  consequents_len
# 199               2                2
# 195               2                2
# 181               1                2
# 187               1                2
# 194               2                2

# %%
rules.count()
# Out:
# antecedents           49
# consequents           49
# antecedent support    49
# consequent support    49
# support               49
# confidence            49
# lift                  49
# leverage              49
# conviction            49
# antecedent_len        49
# consequents_len       49
# dtype: int64

# %%
#Prune the rules for better Confidence
rules =rules[rules['confidence']>0.5]
rules.head()
# Out:
#                                            antecedents  \
# 199  (SET/20 RED RETROSPOT PAPER NAPKINS, SET/6 RED...
# 195  (SET/6 RED SPOTTY PAPER PLATES, SET/20 RED RET...
# 181                    (SET/6 RED SPOTTY PAPER PLATES)
# 187                    (SET/6 RED SPOTTY PAPER PLATES)
# 194           (SET/6 RED SPOTTY PAPER PLATES, POSTAGE)
#
#                                            consequents  antecedent support  \
# 199           (SET/6 RED SPOTTY PAPER PLATES, POSTAGE)            0.086768
# 195             (POSTAGE, SET/6 RED SPOTTY PAPER CUPS)            0.086768
# 181             (POSTAGE, SET/6 RED SPOTTY PAPER CUPS)            0.108460
# 187  (SET/20 RED RETROSPOT PAPER NAPKINS, SET/6 RED...            0.108460
# 194  (SET/20 RED RETROSPOT PAPER NAPKINS, SET/6 RED...            0.091106
#
#      consequent support   support  confidence      lift  leverage  conviction  \
# 199            0.091106  0.069414    0.800000  8.780952  0.061509    4.544469
# 195            0.099783  0.069414    0.800000  8.017391  0.060756    4.501085
# 181            0.099783  0.086768    0.800000  8.017391  0.075945    4.501085
# 187            0.086768  0.084599    0.780000  8.989500  0.075188    4.151055
# 194            0.086768  0.069414    0.761905  8.780952  0.061509    3.835575
#
#      antecedent_len  consequents_len
# 199               2                2
# 195               2                2
# 181               1                2
# 187               1                2
# 194               2                2

# %%
rules.count()
# Out:
# antecedents           29
# consequents           29
# antecedent support    29
# consequent support    29
# support               29
# confidence            29
# lift                  29
# leverage              29
# conviction            29
# antecedent_len        29
# consequents_len       29
# dtype: int64

# %%
#Measure performance of Rules
rules =rules[rules['lift']>=3]
rules.head()
# Out:
#                                            antecedents  \
# 199  (SET/20 RED RETROSPOT PAPER NAPKINS, SET/6 RED...
# 195  (SET/6 RED SPOTTY PAPER PLATES, SET/20 RED RET...
# 181                    (SET/6 RED SPOTTY PAPER PLATES)
# 187                    (SET/6 RED SPOTTY PAPER PLATES)
# 194           (SET/6 RED SPOTTY PAPER PLATES, POSTAGE)
#
#                                            consequents  antecedent support  \
# 199           (SET/6 RED SPOTTY PAPER PLATES, POSTAGE)            0.086768
# 195             (POSTAGE, SET/6 RED SPOTTY PAPER CUPS)            0.086768
# 181             (POSTAGE, SET/6 RED SPOTTY PAPER CUPS)            0.108460
# 187  (SET/20 RED RETROSPOT PAPER NAPKINS, SET/6 RED...            0.108460
# 194  (SET/20 RED RETROSPOT PAPER NAPKINS, SET/6 RED...            0.091106
#
#      consequent support   support  confidence      lift  leverage  conviction  \
# 199            0.091106  0.069414    0.800000  8.780952  0.061509    4.544469
# 195            0.099783  0.069414    0.800000  8.017391  0.060756    4.501085
# 181            0.099783  0.086768    0.800000  8.017391  0.075945    4.501085
# 187            0.086768  0.084599    0.780000  8.989500  0.075188    4.151055
# 194            0.086768  0.069414    0.761905  8.780952  0.061509    3.835575
#
#      antecedent_len  consequents_len
# 199               2                2
# 195               2                2
# 181               1                2
# 187               1                2
# 194               2                2

# %%
rules.count()
# Out:
# antecedents           29
# consequents           29
# antecedent support    29
# consequent support    29
# support               29
# confidence            29
# lift                  29
# leverage              29
# conviction            29
# antecedent_len        29
# consequents_len       29
# dtype: int64

# %%
#Remove less important/useful Rules
rules =rules[rules['conviction']>=3]
rules.head()
# Out:
#                                            antecedents  \
# 199  (SET/20 RED RETROSPOT PAPER NAPKINS, SET/6 RED...
# 195  (SET/6 RED SPOTTY PAPER PLATES, SET/20 RED RET...
# 181                    (SET/6 RED SPOTTY PAPER PLATES)
# 187                    (SET/6 RED SPOTTY PAPER PLATES)
# 194           (SET/6 RED SPOTTY PAPER PLATES, POSTAGE)
#
#                                            consequents  antecedent support  \
# 199           (SET/6 RED SPOTTY PAPER PLATES, POSTAGE)            0.086768
# 195             (POSTAGE, SET/6 RED SPOTTY PAPER CUPS)            0.086768
# 181             (POSTAGE, SET/6 RED SPOTTY PAPER CUPS)            0.108460
# 187  (SET/20 RED RETROSPOT PAPER NAPKINS, SET/6 RED...            0.108460
# 194  (SET/20 RED RETROSPOT PAPER NAPKINS, SET/6 RED...            0.091106
#
#      consequent support   support  confidence      lift  leverage  conviction  \
# 199            0.091106  0.069414    0.800000  8.780952  0.061509    4.544469
# 195            0.099783  0.069414    0.800000  8.017391  0.060756    4.501085
# 181            0.099783  0.086768    0.800000  8.017391  0.075945    4.501085
# 187            0.086768  0.084599    0.780000  8.989500  0.075188    4.151055
# 194            0.086768  0.069414    0.761905  8.780952  0.061509    3.835575
#
#      antecedent_len  consequents_len
# 199               2                2
# 195               2                2
# 181               1                2
# 187               1                2
# 194               2                2

# %%
rules.count()
# Out:
# antecedents           13
# consequents           13
# antecedent support    13
# consequent support    13
# support               13
# confidence            13
# lift                  13
# leverage              13
# conviction            13
# antecedent_len        13
# consequents_len       13
# dtype: int64

# %%
rules
# Out:
#                                            antecedents  \
# 199  (SET/20 RED RETROSPOT PAPER NAPKINS, SET/6 RED...
# 195  (SET/6 RED SPOTTY PAPER PLATES, SET/20 RED RET...
# 181                    (SET/6 RED SPOTTY PAPER PLATES)
# 187                    (SET/6 RED SPOTTY PAPER PLATES)
# 194           (SET/6 RED SPOTTY PAPER PLATES, POSTAGE)
# 127                         (ALARM CLOCK BAKELIKE RED)
# 188               (SET/20 RED RETROSPOT PAPER NAPKINS)
# 197      (POSTAGE, SET/20 RED RETROSPOT PAPER NAPKINS)
# 183                      (SET/6 RED SPOTTY PAPER CUPS)
# 129                       (ALARM CLOCK BAKELIKE GREEN)
# 189                      (SET/6 RED SPOTTY PAPER CUPS)
# 133                         (ALARM CLOCK BAKELIKE RED)
# 198             (POSTAGE, SET/6 RED SPOTTY PAPER CUPS)
#
#                                            consequents  antecedent support  \
# 199           (SET/6 RED SPOTTY PAPER PLATES, POSTAGE)            0.086768
# 195             (POSTAGE, SET/6 RED SPOTTY PAPER CUPS)            0.086768
# 181             (POSTAGE, SET/6 RED SPOTTY PAPER CUPS)            0.108460
# 187  (SET/20 RED RETROSPOT PAPER NAPKINS, SET/6 RED...            0.108460
# 194  (SET/20 RED RETROSPOT PAPER NAPKINS, SET/6 RED...            0.091106
# 127              (POSTAGE, ALARM CLOCK BAKELIKE GREEN)            0.080260
# 188  (SET/6 RED SPOTTY PAPER PLATES, SET/6 RED SPOT...            0.112798
# 197  (SET/6 RED SPOTTY PAPER PLATES, SET/6 RED SPOT...            0.093275
# 183           (SET/6 RED SPOTTY PAPER PLATES, POSTAGE)            0.117137
# 129                (ALARM CLOCK BAKELIKE RED, POSTAGE)            0.082430
# 189  (SET/6 RED SPOTTY PAPER PLATES, SET/20 RED RET...            0.117137
# 133               (POSTAGE, ALARM CLOCK BAKELIKE PINK)            0.080260
# 198  (SET/6 RED SPOTTY PAPER PLATES, SET/20 RED RET...            0.099783
#
#      consequent support   support  confidence       lift  leverage  \
# 199            0.091106  0.069414    0.800000   8.780952  0.061509
# 195            0.099783  0.069414    0.800000   8.017391  0.060756
# 181            0.099783  0.086768    0.800000   8.017391  0.075945
# 187            0.086768  0.084599    0.780000   8.989500  0.075188
# 194            0.086768  0.069414    0.761905   8.780952  0.061509
# 127            0.071584  0.060738    0.756757  10.571663  0.054992
# 188            0.104121  0.084599    0.750000   7.203125  0.072854
# 197            0.104121  0.069414    0.744186   7.147287  0.059702
# 183            0.091106  0.086768    0.740741   8.130511  0.076096
# 129            0.073753  0.060738    0.736842   9.990712  0.054658
# 189            0.086768  0.084599    0.722222   8.323611  0.074435
# 133            0.075922  0.056399    0.702703   9.255598  0.050306
# 198            0.086768  0.069414    0.695652   8.017391  0.060756
#
#      conviction  antecedent_len  consequents_len
# 199    4.544469               2                2
# 195    4.501085               2                2
# 181    4.501085               1                2
# 187    4.151055               1                2
# 194    3.835575               2                2
# 127    3.816823               1                2
# 188    3.583514               1                2
# 197    3.502071               2                2
# 183    3.505733               1                2
# 129    3.519740               1                2
# 189    3.287636               1                2
# 133    3.108263               1                2
# 198    3.000620               2                2

# %%
#Given Assignment mention to have 1 antecedent
rules = rules[rules['antecedent_len']==1]
rules
# Out:
#                               antecedents  \
# 181       (SET/6 RED SPOTTY PAPER PLATES)
# 187       (SET/6 RED SPOTTY PAPER PLATES)
# 127            (ALARM CLOCK BAKELIKE RED)
# 188  (SET/20 RED RETROSPOT PAPER NAPKINS)
# 183         (SET/6 RED SPOTTY PAPER CUPS)
# 129          (ALARM CLOCK BAKELIKE GREEN)
# 189         (SET/6 RED SPOTTY PAPER CUPS)
# 133            (ALARM CLOCK BAKELIKE RED)
#
#                                            consequents  antecedent support  \
# 181             (POSTAGE, SET/6 RED SPOTTY PAPER CUPS)            0.108460
# 187  (SET/20 RED RETROSPOT PAPER NAPKINS, SET/6 RED...            0.108460
# 127              (POSTAGE, ALARM CLOCK BAKELIKE GREEN)            0.080260
# 188  (SET/6 RED SPOTTY PAPER PLATES, SET/6 RED SPOT...            0.112798
# 183           (SET/6 RED SPOTTY PAPER PLATES, POSTAGE)            0.117137
# 129                (ALARM CLOCK BAKELIKE RED, POSTAGE)            0.082430
# 189  (SET/6 RED SPOTTY PAPER PLATES, SET/20 RED RET...            0.117137
# 133               (POSTAGE, ALARM CLOCK BAKELIKE PINK)            0.080260
#
#      consequent support   support  confidence       lift  leverage  \
# 181            0.099783  0.086768    0.800000   8.017391  0.075945
# 187            0.086768  0.084599    0.780000   8.989500  0.075188
# 127            0.071584  0.060738    0.756757  10.571663  0.054992
# 188            0.104121  0.084599    0.750000   7.203125  0.072854
# 183            0.091106  0.086768    0.740741   8.130511  0.076096
# 129            0.073753  0.060738    0.736842   9.990712  0.054658
# 189            0.086768  0.084599    0.722222   8.323611  0.074435
# 133            0.075922  0.056399    0.702703   9.255598  0.050306
#
#      conviction  antecedent_len  consequents_len
# 181    4.501085               1                2
# 187    4.151055               1                2
# 127    3.816823               1                2
# 188    3.583514               1                2
# 183    3.505733               1                2
# 129    3.519740               1                2
# 189    3.287636               1                2
# 133    3.108263               1                2

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'SET/6 RED SPOTTY PAPER PLATES'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-27-d7f99acc7a2a> in <module>
# ----> 1 print(rules['SET/6 RED SPOTTY PAPER PLATES'])
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2660         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2661         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'SET/6 RED SPOTTY PAPER PLATES'

# %%
rules.to_csv("rules.csv")
